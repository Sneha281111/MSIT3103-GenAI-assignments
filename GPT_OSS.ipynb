# %%
# !pip install -q huggingface_hub
from huggingface_hub import login
login()  # paste your token from https://huggingface.co/settings/tokens

# %%
from huggingface_hub import InferenceClient
client = InferenceClient("openai/gpt-oss-20b", token="hf_your_token_here")

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "hf_your_token_here"
from huggingface_hub import InferenceClient
client = InferenceClient("openai/gpt-oss-20b")
